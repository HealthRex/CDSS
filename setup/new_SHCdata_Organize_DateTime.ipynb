# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pulp import *
import pandas as pd
import os, glob
import seaborn as sns
from scipy.stats import kruskal
import scikit_posthocs as sp
from scipy.stats import mannwhitneyu
from dotenv import load_dotenv

load_dotenv('./Credentials.env',override=True)

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] =str(os.getenv("GOOGLE_APPLICATION_CREDENTIALS"))
os.environ['GCLOUD_PROJECT'] = str(os.getenv("GCLOUD_PROJECT"))

# %load_ext google.cloud.bigquery

from google.cloud import bigquery
client=bigquery.Client()
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
from google.cloud import bigquery

def all_available_tables(dataset_name='shc_core_2024', project_id='som-nero-phi-jonc101'):
    try:
        # Initialize BigQuery Client
        client = bigquery.Client()

        # Construct dataset reference
        dataset_ref = client.dataset(dataset_name, project=project_id)

        # List tables in the dataset
        tables = client.list_tables(dataset_ref)

        # Extract table names
        table_names = [table.table_id for table in tables]

        return table_names

    except Exception as e:
        print(f"Error fetching tables: {e}")
        return None

# %%
project_id='som-nero-phi-jonc101'
dataset_name='shc_core_2024'
table_names=all_available_tables(dataset_name,project_id)
table_names
# Out:
# ['adt',
#  'alert',
#  'alert_history',
#  'alerts_orders',
#  'allergy',
#  'clinical_doc_meta',
#  'culture_sensitivity',
#  'demographic',
#  'dep_map',
#  'diagnosis',
#  'drg_code',
#  'encounter',
#  'f_ip_hsp_admission',
#  'family_hx',
#  'flowsheet',
#  'geolocation_from_omop',
#  'ib_messages',
#  'lab_result',
#  'lda',
#  'mapped_meds',
#  'med_orderset',
#  'myc_mesg',
#  'ndc_code',
#  'new_pats',
#  'order_comment',
#  'order_med',
#  'order_proc',
#  'pharmacy_mar',
#  'proc_orderset',
#  'procedure',
#  'prov_map',
#  'social_hx',
#  'treatment_team',
#  'zip']

# %%
from google.cloud import bigquery

def backup_tables(table_names, project_id, dataset_name, new_dataset_name='fatemeh_copy_shc_core_2023'):
    """Copies tables from one dataset to another within the same BigQuery project."""
    try:
        client = bigquery.Client()

        for table in table_names:
            source_table_id = f"{project_id}.{dataset_name}.{table}"
            destination_table_id = f"{project_id}.{new_dataset_name}.{table}"
            
            print(f"Copying table: {source_table_id} → {destination_table_id}")

            job = client.copy_table(source_table_id, destination_table_id)
            job.result()  # Waits for the copy job to complete

            print(f"Successfully copied {table}")

    except Exception as e:
        print(f" Error copying tables: {e}")

# %%
project_id='som-nero-phi-jonc101'
dataset_name='shc_core_2024'
# make a backup from all tables
backup_tables(table_names,project_id,dataset_name,new_dataset_name='copy_shc_core_2024')
# Out:
# Copying table: som-nero-phi-jonc101.shc_core_2024.adt → som-nero-phi-jonc101.fatemeh_db_2024.adt
# ✔ Successfully copied adt
# Copying table: som-nero-phi-jonc101.shc_core_2024.alert → som-nero-phi-jonc101.fatemeh_db_2024.alert
# ✔ Successfully copied alert
# Copying table: som-nero-phi-jonc101.shc_core_2024.alert_history → som-nero-phi-jonc101.fatemeh_db_2024.alert_history
# ✔ Successfully copied alert_history
# Copying table: som-nero-phi-jonc101.shc_core_2024.alerts_orders → som-nero-phi-jonc101.fatemeh_db_2024.alerts_orders
# ✔ Successfully copied alerts_orders
# Copying table: som-nero-phi-jonc101.shc_core_2024.allergy → som-nero-phi-jonc101.fatemeh_db_2024.allergy
# ✔ Successfully copied allergy
# Copying table: som-nero-phi-jonc101.shc_core_2024.clinical_doc_meta → som-nero-phi-jonc101.fatemeh_db_2024.clinical_doc_meta
# ✔ Successfully copied clinical_doc_meta
# Copying table: som-nero-phi-jonc101.shc_core_2024.culture_sensitivity → som-nero-phi-jonc101.fatemeh_db_2024.culture_sensitivity
# ✔ Successfully copied culture_sensitivity
# Copying table: som-nero-phi-jonc101.shc_core_2024.demographic → som-nero-phi-jonc101.fatemeh_db_2024.demographic
# ✔ Successfully copied demographic
# Copying table: som-nero-phi-jonc101.shc_core_2024.dep_map → som-nero-phi-jonc101.fatemeh_db_2024.dep_map
# ✔ Successfully copied dep_map
# Copying table: som-nero-phi-jonc101.shc_core_2024.diagnosis → som-nero-phi-jonc101.fatemeh_db_2024.diagnosis
# ✔ Successfully copied diagnosis
# Copying table: som-nero-phi-jonc101.shc_core_2024.drg_code → som-nero-phi-jonc101.fatemeh_db_2024.drg_code
# ✔ Successfully copied drg_code
# Copying table: som-nero-phi-jonc101.shc_core_2024.encounter → som-nero-phi-jonc101.fatemeh_db_2024.encounter
# ✔ Successfully copied encounter
# Copying table: som-nero-phi-jonc101.shc_core_2024.f_ip_hsp_admission → som-nero-phi-jonc101.fatemeh_db_2024.f_ip_hsp_admission
# ✔ Successfully copied f_ip_hsp_admission
# Copying table: som-nero-phi-jonc101.shc_core_2024.family_hx → som-nero-phi-jonc101.fatemeh_db_2024.family_hx
# ✔ Successfully copied family_hx
# Copying table: som-nero-phi-jonc101.shc_core_2024.flowsheet → som-nero-phi-jonc101.fatemeh_db_2024.flowsheet
# ✔ Successfully copied flowsheet
# Copying table: som-nero-phi-jonc101.shc_core_2024.geolocation_from_omop → som-nero-phi-jonc101.fatemeh_db_2024.geolocation_from_omop
# ✔ Successfully copied geolocation_from_omop
# Copying table: som-nero-phi-jonc101.shc_core_2024.ib_messages → som-nero-phi-jonc101.fatemeh_db_2024.ib_messages
# ✔ Successfully copied ib_messages
# Copying table: som-nero-phi-jonc101.shc_core_2024.lab_result → som-nero-phi-jonc101.fatemeh_db_2024.lab_result
# ✔ Successfully copied lab_result
# Copying table: som-nero-phi-jonc101.shc_core_2024.lda → som-nero-phi-jonc101.fatemeh_db_2024.lda
# ✔ Successfully copied lda
# Copying table: som-nero-phi-jonc101.shc_core_2024.mapped_meds → som-nero-phi-jonc101.fatemeh_db_2024.mapped_meds
# ✔ Successfully copied mapped_meds
# Copying table: som-nero-phi-jonc101.shc_core_2024.med_orderset → som-nero-phi-jonc101.fatemeh_db_2024.med_orderset
# ✔ Successfully copied med_orderset
# Copying table: som-nero-phi-jonc101.shc_core_2024.myc_mesg → som-nero-phi-jonc101.fatemeh_db_2024.myc_mesg
# ✔ Successfully copied myc_mesg
# Copying table: som-nero-phi-jonc101.shc_core_2024.ndc_code → som-nero-phi-jonc101.fatemeh_db_2024.ndc_code
# ✔ Successfully copied ndc_code
# Copying table: som-nero-phi-jonc101.shc_core_2024.new_pats → som-nero-phi-jonc101.fatemeh_db_2024.new_pats
# ✔ Successfully copied new_pats
# Copying table: som-nero-phi-jonc101.shc_core_2024.order_comment → som-nero-phi-jonc101.fatemeh_db_2024.order_comment
# ✔ Successfully copied order_comment
# Copying table: som-nero-phi-jonc101.shc_core_2024.order_med → som-nero-phi-jonc101.fatemeh_db_2024.order_med
# ✔ Successfully copied order_med
# Copying table: som-nero-phi-jonc101.shc_core_2024.order_proc → som-nero-phi-jonc101.fatemeh_db_2024.order_proc
# ✔ Successfully copied order_proc
# Copying table: som-nero-phi-jonc101.shc_core_2024.pharmacy_mar → som-nero-phi-jonc101.fatemeh_db_2024.pharmacy_mar
# ✔ Successfully copied pharmacy_mar
# Copying table: som-nero-phi-jonc101.shc_core_2024.proc_orderset → som-nero-phi-jonc101.fatemeh_db_2024.proc_orderset
# ✔ Successfully copied proc_orderset
# Copying table: som-nero-phi-jonc101.shc_core_2024.procedure → som-nero-phi-jonc101.fatemeh_db_2024.procedure
# ✔ Successfully copied procedure
# Copying table: som-nero-phi-jonc101.shc_core_2024.prov_map → som-nero-phi-jonc101.fatemeh_db_2024.prov_map
# ✔ Successfully copied prov_map
# Copying table: som-nero-phi-jonc101.shc_core_2024.social_hx → som-nero-phi-jonc101.fatemeh_db_2024.social_hx
# ✔ Successfully copied social_hx
# Copying table: som-nero-phi-jonc101.shc_core_2024.treatment_team → som-nero-phi-jonc101.fatemeh_db_2024.treatment_team
# ✔ Successfully copied treatment_team
# Copying table: som-nero-phi-jonc101.shc_core_2024.zip → som-nero-phi-jonc101.fatemeh_db_2024.zip
# ✔ Successfully copied zip

# %%
def all_timestamp_columns(table_name, dataset_name='shc_core_2023', project_id='som-nero-phi-jonc101'):
    """
    Retrieves all columns of type TIMESTAMP or DATETIME from a BigQuery table.
    """
    try:
        # Initialize BigQuery client
        client = bigquery.Client()

        # Get table schema
        full_table_name = f"{project_id}.{dataset_name}.{table_name}"
        table = client.get_table(full_table_name)

        # Extract TIMESTAMP or DATETIME columns
        datetime_cols = [field.name for field in table.schema if field.field_type in ['TIMESTAMP', 'DATETIME']]

        return datetime_cols

    except Exception as e:
        print(f"Error fetching schema for {full_table_name}: {e}")
        return None

# %%
from google.cloud import bigquery

def convert_string_to_datetime(table_name, dataset_name, project_id):
    """
    Identifies STRING columns in a BigQuery table that can be converted to DATETIME or DATE.
    Returns lists of columns that can be converted.
    """
    try:
        client = bigquery.Client()

        # Construct table reference
        full_table_name = f"{project_id}.{dataset_name}.{table_name}"
        table = client.get_table(full_table_name)

        # Identify STRING columns
        string_columns = [field.name for field in table.schema if field.field_type == "STRING"]

        string_datetime_cols = []
        string_date_cols = []

        for column in string_columns:
            query = f"""
                SELECT 
                    COUNTIF(SAFE.PARSE_DATETIME('%Y-%m-%d %H:%M:%S', {column}) IS NOT NULL) AS datetime_count,
                    COUNTIF(SAFE.PARSE_DATE('%Y-%m-%d', {column}) IS NOT NULL) AS date_count
                FROM `{full_table_name}`;
            """

            results = client.query(query).result()

            for row in results:
                if row.datetime_count > 0:
                    string_datetime_cols.append(column)
                if row.date_count > 0:
                    string_date_cols.append(column)

        return string_datetime_cols, string_date_cols

    except Exception as e:
        print(f"❌ Error processing table {full_table_name}: {e}")
        return None, None

# %%
def fix_datetime(datetime_columns, date_columns, table_name, dataset_name, project_id):
    """
    Converts specified STRING columns into DATETIME or DATE format and updates the BigQuery table.
    """
    try:
        client = bigquery.Client()

        # Construct table references
        full_table_name = f"{project_id}.{dataset_name}.{table_name}"
        new_table_name = full_table_name  # Keeps the same table name

        # Merge datetime and date columns
        all_columns = datetime_columns + date_columns

        # Generate SQL conversion expressions
        formatted_expressions = []
        for col in datetime_columns:
            formatted_expressions.append(f"SAFE.PARSE_DATETIME('%Y-%m-%d %H:%M:%S', {col}) AS {col}")

        for col in date_columns:
            formatted_expressions.append(f"SAFE.PARSE_DATE('%Y-%m-%d', {col}) AS {col}")

        query = f"""
            CREATE OR REPLACE TABLE `{new_table_name}` AS
            SELECT * EXCEPT({', '.join(all_columns)}), {', '.join(formatted_expressions)}
            FROM `{full_table_name}`;
        """

        print("Executing query:\n", query)

        # Run the query
        job = client.query(query)
        job.result()  # Wait for completion

        print(f"✔ Successfully updated table `{new_table_name}` with corrected datetime formats.")

    except Exception as e:
        print(f"❌ Error converting datetime columns: {e}")

# %%
from google.cloud import bigquery

def convert_la_to_utc(columns, table_name, dataset_name='shc_core_2023', project_id='som-nero-phi-jonc101'):
    """
    Converts specified timestamp columns from America/Los_Angeles (PST/PDT) to UTC in a BigQuery table.
    """
    try:
        client = bigquery.Client()

        # Construct table references
        full_table_name = f"{project_id}.{dataset_name}.{table_name}"
        new_table_name = full_table_name  # Keeps the same table name

        # Generate SQL query for UTC conversion
        utc_columns = [
            f"TIMESTAMP({col}, 'America/Los_Angeles') AS {col}_utc"
            for col in columns
        ]
        
        query = f"""
            CREATE OR REPLACE TABLE `{new_table_name}` AS
            SELECT *, {', '.join(utc_columns)}
            FROM `{full_table_name}`;
        """

        print("Executing query:\n", query)

        # Run the query
        job = client.query(query)
        job.result()  # Wait for completion

        print(f"✔ Successfully updated table `{new_table_name}` with UTC timestamps.")

    except Exception as e:
        print(f"❌ Error converting timestamps: {e}")

# %%
for table in table_names:
    
    datetimecolumns=all_timestamp_columns(table_name=table,dataset_name=dataset_name,project_id=project_id)
    print(datetimecolumns)
    if len(datetimecolumns)>0:
        convert_la_to_utc(columns=datetimecolumns,table_name=table,dataset_name=dataset_name,project_id=project_id)
# Out:
# adt
# ['effective_time_jittered', 'event_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.adt` AS
#             SELECT *, TIMESTAMP(effective_time_jittered, 'America/Los_Angeles') AS effective_time_jittered_utc, TIMESTAMP(event_time_jittered, 'America/Los_Angeles') AS event_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.adt`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.adt` with UTC timestamps.
# ****************************************************
# alert
# ['update_date_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.alert` AS
#             SELECT *, TIMESTAMP(update_date_jittered, 'America/Los_Angeles') AS update_date_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.alert`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.alert` with UTC timestamps.
# ****************************************************
# alert_history
# ['update_date_jittered', 'contact_date', 'alt_action_inst']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.alert_history` AS
#             SELECT *, TIMESTAMP(update_date_jittered, 'America/Los_Angeles') AS update_date_jittered_utc, TIMESTAMP(contact_date, 'America/Los_Angeles') AS contact_date_utc, TIMESTAMP(alt_action_inst, 'America/Los_Angeles') AS alt_action_inst_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.alert_history`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.alert_history` with UTC timestamps.
# ****************************************************
# alerts_orders
# ['update_date_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.alerts_orders` AS
#             SELECT *, TIMESTAMP(update_date_jittered, 'America/Los_Angeles') AS update_date_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.alerts_orders`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.alerts_orders` with UTC timestamps.
# ****************************************************
# allergy
# ['date_noted_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.allergy` AS
#             SELECT *, TIMESTAMP(date_noted_jittered, 'America/Los_Angeles') AS date_noted_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.allergy`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.allergy` with UTC timestamps.
# ****************************************************
# clinical_doc_meta
# ['filing_date_jittered', 'note_date_jittered', 'activity_date_jittered', 'effective_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.clinical_doc_meta` AS
#             SELECT *, TIMESTAMP(filing_date_jittered, 'America/Los_Angeles') AS filing_date_jittered_utc, TIMESTAMP(note_date_jittered, 'America/Los_Angeles') AS note_date_jittered_utc, TIMESTAMP(activity_date_jittered, 'America/Los_Angeles') AS activity_date_jittered_utc, TIMESTAMP(effective_time_jittered, 'America/Los_Angeles') AS effective_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.clinical_doc_meta`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.clinical_doc_meta` with UTC timestamps.
# ****************************************************
# culture_sensitivity
# ['order_time_jittered', 'result_time_jittered', 'sens_obs_inst_tm_jittered', 'sens_anl_inst_tm_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.culture_sensitivity` AS
#             SELECT *, TIMESTAMP(order_time_jittered, 'America/Los_Angeles') AS order_time_jittered_utc, TIMESTAMP(result_time_jittered, 'America/Los_Angeles') AS result_time_jittered_utc, TIMESTAMP(sens_obs_inst_tm_jittered, 'America/Los_Angeles') AS sens_obs_inst_tm_jittered_utc, TIMESTAMP(sens_anl_inst_tm_jittered, 'America/Los_Angeles') AS sens_anl_inst_tm_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.culture_sensitivity`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.culture_sensitivity` with UTC timestamps.
# ****************************************************
# demographic
# ['birth_date_jittered', 'death_date_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.demographic` AS
#             SELECT *, TIMESTAMP(birth_date_jittered, 'America/Los_Angeles') AS birth_date_jittered_utc, TIMESTAMP(death_date_jittered, 'America/Los_Angeles') AS death_date_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.demographic`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.demographic` with UTC timestamps.
# ****************************************************
# dep_map
# []
# ****************************************************
# diagnosis
# ['start_date_jittered', 'noted_date_jittered', 'hx_date_of_entry_jittered', 'resolved_date_jittered', 'end_date_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.diagnosis` AS
#             SELECT *, TIMESTAMP(start_date_jittered, 'America/Los_Angeles') AS start_date_jittered_utc, TIMESTAMP(noted_date_jittered, 'America/Los_Angeles') AS noted_date_jittered_utc, TIMESTAMP(hx_date_of_entry_jittered, 'America/Los_Angeles') AS hx_date_of_entry_jittered_utc, TIMESTAMP(resolved_date_jittered, 'America/Los_Angeles') AS resolved_date_jittered_utc, TIMESTAMP(end_date_jittered, 'America/Los_Angeles') AS end_date_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.diagnosis`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.diagnosis` with UTC timestamps.
# ****************************************************
# drg_code
# []
# ****************************************************
# encounter
# ['contact_date_jittered', 'adt_arrival_time_jittered', 'hosp_admsn_time_jittered', 'hosp_disch_time_jittered', 'appt_time_jittered', 'appt_when_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.encounter` AS
#             SELECT *, TIMESTAMP(contact_date_jittered, 'America/Los_Angeles') AS contact_date_jittered_utc, TIMESTAMP(adt_arrival_time_jittered, 'America/Los_Angeles') AS adt_arrival_time_jittered_utc, TIMESTAMP(hosp_admsn_time_jittered, 'America/Los_Angeles') AS hosp_admsn_time_jittered_utc, TIMESTAMP(hosp_disch_time_jittered, 'America/Los_Angeles') AS hosp_disch_time_jittered_utc, TIMESTAMP(appt_time_jittered, 'America/Los_Angeles') AS appt_time_jittered_utc, TIMESTAMP(appt_when_jittered, 'America/Los_Angeles') AS appt_when_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.encounter`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.encounter` with UTC timestamps.
# ****************************************************
# f_ip_hsp_admission
# ['hosp_adm_date_jittered', 'hosp_disch_date_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.f_ip_hsp_admission` AS
#             SELECT *, TIMESTAMP(hosp_adm_date_jittered, 'America/Los_Angeles') AS hosp_adm_date_jittered_utc, TIMESTAMP(hosp_disch_date_jittered, 'America/Los_Angeles') AS hosp_disch_date_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.f_ip_hsp_admission`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.f_ip_hsp_admission` with UTC timestamps.
# ****************************************************
# family_hx
# []
# ****************************************************
# flowsheet
# ['recorded_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.flowsheet` AS
#             SELECT *, TIMESTAMP(recorded_time_jittered, 'America/Los_Angeles') AS recorded_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.flowsheet`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.flowsheet` with UTC timestamps.
# ****************************************************
# geolocation_from_omop
# []
# ****************************************************
# ib_messages
# ['create_time_jittered', 'send_on_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.ib_messages` AS
#             SELECT *, TIMESTAMP(create_time_jittered, 'America/Los_Angeles') AS create_time_jittered_utc, TIMESTAMP(send_on_jittered, 'America/Los_Angeles') AS send_on_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.ib_messages`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.ib_messages` with UTC timestamps.
# ****************************************************
# lab_result
# ['order_time_jittered', 'taken_time_jittered', 'result_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.lab_result` AS
#             SELECT *, TIMESTAMP(order_time_jittered, 'America/Los_Angeles') AS order_time_jittered_utc, TIMESTAMP(taken_time_jittered, 'America/Los_Angeles') AS taken_time_jittered_utc, TIMESTAMP(result_time_jittered, 'America/Los_Angeles') AS result_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.lab_result`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.lab_result` with UTC timestamps.
# ****************************************************
# lda
# ['placement_instant_jittered', 'removal_instant_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.lda` AS
#             SELECT *, TIMESTAMP(placement_instant_jittered, 'America/Los_Angeles') AS placement_instant_jittered_utc, TIMESTAMP(removal_instant_jittered, 'America/Los_Angeles') AS removal_instant_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.lda`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.lda` with UTC timestamps.
# ****************************************************
# mapped_meds
# []
# ****************************************************
# med_orderset
# []
# ****************************************************
# myc_mesg
# ['created_time_jittered', 'final_handled_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.myc_mesg` AS
#             SELECT *, TIMESTAMP(created_time_jittered, 'America/Los_Angeles') AS created_time_jittered_utc, TIMESTAMP(final_handled_time_jittered, 'America/Los_Angeles') AS final_handled_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.myc_mesg`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.myc_mesg` with UTC timestamps.
# ****************************************************
# ndc_code
# []
# ****************************************************
# new_pats
# []
# ****************************************************
# order_comment
# ['order_inst_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.order_comment` AS
#             SELECT *, TIMESTAMP(order_inst_jittered, 'America/Los_Angeles') AS order_inst_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.order_comment`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.order_comment` with UTC timestamps.
# ****************************************************
# order_med
# ['ordering_date_jittered', 'start_date_jittered', 'end_date_jittered', 'order_start_time_jittered', 'order_end_time_jittered', 'order_inst_jittered', 'discon_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.order_med` AS
#             SELECT *, TIMESTAMP(ordering_date_jittered, 'America/Los_Angeles') AS ordering_date_jittered_utc, TIMESTAMP(start_date_jittered, 'America/Los_Angeles') AS start_date_jittered_utc, TIMESTAMP(end_date_jittered, 'America/Los_Angeles') AS end_date_jittered_utc, TIMESTAMP(order_start_time_jittered, 'America/Los_Angeles') AS order_start_time_jittered_utc, TIMESTAMP(order_end_time_jittered, 'America/Los_Angeles') AS order_end_time_jittered_utc, TIMESTAMP(order_inst_jittered, 'America/Los_Angeles') AS order_inst_jittered_utc, TIMESTAMP(discon_time_jittered, 'America/Los_Angeles') AS discon_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.order_med`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.order_med` with UTC timestamps.
# ****************************************************
# order_proc
# ['ordering_date_jittered', 'standing_exp_date_jittered', 'proc_bgn_time_jittered', 'proc_end_time_jittered', 'order_inst_jittered', 'instantiated_time_jittered', 'order_time_jittered', 'result_time_jittered', 'proc_start_time_jittered', 'proc_date_jittered', 'last_stand_perf_dt_jittered', 'last_stand_perf_tm_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.order_proc` AS
#             SELECT *, TIMESTAMP(ordering_date_jittered, 'America/Los_Angeles') AS ordering_date_jittered_utc, TIMESTAMP(standing_exp_date_jittered, 'America/Los_Angeles') AS standing_exp_date_jittered_utc, TIMESTAMP(proc_bgn_time_jittered, 'America/Los_Angeles') AS proc_bgn_time_jittered_utc, TIMESTAMP(proc_end_time_jittered, 'America/Los_Angeles') AS proc_end_time_jittered_utc, TIMESTAMP(order_inst_jittered, 'America/Los_Angeles') AS order_inst_jittered_utc, TIMESTAMP(instantiated_time_jittered, 'America/Los_Angeles') AS instantiated_time_jittered_utc, TIMESTAMP(order_time_jittered, 'America/Los_Angeles') AS order_time_jittered_utc, TIMESTAMP(result_time_jittered, 'America/Los_Angeles') AS result_time_jittered_utc, TIMESTAMP(proc_start_time_jittered, 'America/Los_Angeles') AS proc_start_time_jittered_utc, TIMESTAMP(proc_date_jittered, 'America/Los_Angeles') AS proc_date_jittered_utc, TIMESTAMP(last_stand_perf_dt_jittered, 'America/Los_Angeles') AS last_stand_perf_dt_jittered_utc, TIMESTAMP(last_stand_perf_tm_jittered, 'America/Los_Angeles') AS last_stand_perf_tm_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.order_proc`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.order_proc` with UTC timestamps.
# ****************************************************
# pharmacy_mar
# ['taken_time_jittered', 'scheduled_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.pharmacy_mar` AS
#             SELECT *, TIMESTAMP(taken_time_jittered, 'America/Los_Angeles') AS taken_time_jittered_utc, TIMESTAMP(scheduled_time_jittered, 'America/Los_Angeles') AS scheduled_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.pharmacy_mar`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.pharmacy_mar` with UTC timestamps.
# ****************************************************
# proc_orderset
# []
# ****************************************************
# procedure
# ['start_date_jittered', 'proc_date_jittered', 'adm_date_time_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.procedure` AS
#             SELECT *, TIMESTAMP(start_date_jittered, 'America/Los_Angeles') AS start_date_jittered_utc, TIMESTAMP(proc_date_jittered, 'America/Los_Angeles') AS proc_date_jittered_utc, TIMESTAMP(adm_date_time_jittered, 'America/Los_Angeles') AS adm_date_time_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.procedure`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.procedure` with UTC timestamps.
# ****************************************************
# prov_map
# []
# ****************************************************
# social_hx
# []
# ****************************************************
# treatment_team
# ['trtmnt_tm_begin_dt_jittered', 'trtmnt_tm_end_dt_jittered']
# Executing query:
#
#             CREATE OR REPLACE TABLE `som-nero-phi-jonc101.shc_core_2024.treatment_team` AS
#             SELECT *, TIMESTAMP(trtmnt_tm_begin_dt_jittered, 'America/Los_Angeles') AS trtmnt_tm_begin_dt_jittered_utc, TIMESTAMP(trtmnt_tm_end_dt_jittered, 'America/Los_Angeles') AS trtmnt_tm_end_dt_jittered_utc
#             FROM `som-nero-phi-jonc101.shc_core_2024.treatment_team`;
#
# ✔ Successfully updated table `som-nero-phi-jonc101.shc_core_2024.treatment_team` with UTC timestamps.
# ****************************************************
# zip
# []
# ****************************************************
