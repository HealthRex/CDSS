# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# %load_ext google.cloud.bigquery
from google.cloud import bigquery

client=bigquery.Client()
project_id = "som-nero-phi-jonc101"

# %%
table_id_base_cohort_with_labels_exlucsion = f"{project_id}.blood_culture_stewardship_sandy_2024.enriched_label_filtered"

# %%
query = f"""
WITH demos AS (
    SELECT 
        c.*,
        demo.gender,

        -- BMI capping logic (replace 10 and 80 with your preferred thresholds)
        CASE 
            WHEN demo.bmi IS NULL THEN NULL
            WHEN demo.bmi < 0 THEN NULL          -- too low → set null
            WHEN demo.bmi > 200 THEN NULL          -- too high → set null
            ELSE demo.bmi                         -- keep valid BMI
        END AS bmi,

        CASE 
            WHEN demo.birth_date_jittered_utc IS NOT NULL 
            THEN DATE_DIFF(DATE(c.blood_culture_order_datetime_utc), DATE(demo.birth_date_jittered_utc), DAY) / 365.0
            ELSE NULL
        END AS age,

        CASE
            WHEN demo.birth_date_jittered_utc IS NOT NULL
            THEN DATE_DIFF(DATE(c.blood_culture_order_datetime_utc), DATE(demo.birth_date_jittered_utc), DAY)
            ELSE NULL
        END AS age_days

    FROM `{table_id_base_cohort_with_labels_exlucsion}` c
    LEFT JOIN `som-nero-phi-jonc101.shc_core_2024.demographic` demo
    ON c.anon_id = demo.anon_id
)

SELECT *
FROM demos
WHERE age <= 18
"""

PEDs_ED_BCx_order_cohort_strict_bmi_age_gender= client.query(query).to_dataframe()

# %%
PEDs_ED_BCx_order_cohort_strict_bmi_age_gender

# %%
# print("this is enriched label for adult only and prevalence at set level")
# PEDs_ED_BCx_order_cohort_strict_bmi_age_gender["set_level_label"].value_counts(normalize=True)

# print("this is enriched label for adult only and prevalence at encounter level")

# PEDs_ED_BCx_order_cohort_strict_bmi_age_gender.drop_duplicates(subset=["anon_id", "pat_enc_csn_id_coded"])["final_label"].value_counts(normalize=True)

# %%
df_sorted = PEDs_ED_BCx_order_cohort_strict_bmi_age_gender.sort_values(
    ['anon_id', 'pat_enc_csn_id_coded', 'blood_culture_order_datetime_utc']
)

PEDs_ED_BCx_order_cohort_strict_bmi_age_gender_latest = (
    df_sorted
    .groupby(['anon_id', 'pat_enc_csn_id_coded'], as_index=False)
    .tail(1)
    .reset_index(drop=True)
)

# %%
# table_id_analyse_cohort_withfinal_label_peds = f"{project_id}.blood_culture_stewardship_sandy_2024.enriched_label_filtered_peds_only_analysis_cohort"

# # Upload the DataFrame to BigQuery
# PEDs_ED_BCx_order_cohort_strict_bmi_age_gender_latest.to_gbq(
#     destination_table=table_id_analyse_cohort_withfinal_label_peds,
#     project_id=project_id,
#     if_exists='replace'  # This will replace the table if it exists
# )

# print(f"Uploaded PEDs_ED_BCx_order_cohort_strict_bmi_age_gender to {table_id_analyse_cohort_withfinal_label_peds}")

# %%
test_cohort = PEDs_ED_BCx_order_cohort_strict_bmi_age_gender_latest[PEDs_ED_BCx_order_cohort_strict_bmi_age_gender_latest["order_year"] >= 2023]

# %%
test_cohort = PEDs_ED_BCx_order_cohort_strict_bmi_age_gender_latest[PEDs_ED_BCx_order_cohort_strict_bmi_age_gender_latest["order_year"] >= 2021]

# %%
test_cohort["final_label"].value_counts()

# %%
# df has a column 'label' where 1=positive, 0=negative
positive_sample = test_cohort[test_cohort['final_label'] == "positive"].sample(n=60, random_state=42)
negative_sample = test_cohort[test_cohort['final_label'] != "positive"].sample(n=40, random_state=42)

balanced_300 = pd.concat([positive_sample, negative_sample]).sample(frac=1, random_state=42)

# %%
query = """
WITH unique_mrn AS (
    SELECT anon_id
    FROM `som-nero-phi-jonc101-secure.starr_map.shc_map_2025-07-17`
    GROUP BY anon_id
    HAVING COUNT(*) = 1
)
SELECT DISTINCT mrn.*
FROM `som-nero-phi-jonc101-secure.starr_map.shc_map_2025-07-17` AS mrn
JOIN unique_mrn u ON mrn.anon_id = u.anon_id
JOIN `som-nero-phi-jonc101.blood_culture_stewardship_sandy_2024.enriched_label_filtered_peds_only_analysis_cohort` AS cohort
  ON mrn.anon_id = cohort.anon_id
WHERE cohort.order_year >= 2021
"""
mrn_mapping_test_cohort = client.query(query).to_dataframe()

# %%
mrn_mapping_test_cohort

# %%
test_cohort_with_mrn = test_cohort.merge(mrn_mapping_test_cohort, on="anon_id", how="inner")

# %%
# if jitter might be a string column, coerce to numeric first
test_cohort_with_mrn["jitter_days"] = pd.to_numeric(test_cohort_with_mrn["jitter"], errors="coerce")

test_cohort_with_mrn["candidate_epic_time"] = (
    test_cohort_with_mrn["blood_culture_order_datetime"]
    - pd.to_timedelta(test_cohort_with_mrn["jitter_days"], unit="D")  # negative values fine
    # - pd.Timedelta(hours=8)
)

# %%
columns_to_keep = ["anon_id", "mrn", "pat_enc_csn_id_coded","blood_culture_order_datetime", "blood_culture_order_datetime_utc", "jitter_days","candidate_epic_time", "final_label"]

# %%
test_cohort_with_mrn_columns_to_keep = test_cohort_with_mrn[columns_to_keep]

# %%
positive_sample = test_cohort_with_mrn_columns_to_keep[test_cohort_with_mrn_columns_to_keep['final_label'] == "positive"].sample(n=180, random_state=42)
negative_sample = test_cohort_with_mrn_columns_to_keep[test_cohort_with_mrn_columns_to_keep['final_label'] != "positive"].sample(n=120, random_state=42)

balanced_300 = pd.concat([positive_sample, negative_sample]).sample(frac=1, random_state=42)

# %%
balanced_300

# %%
balanced_300.to_csv("../data/peds_mrn_mapping_balanced_300.csv", index=False)

# %%
pd.read_csv("../data/peds_mrn_mapping_balanced_300.csv")

# %%
df = pd.read_csv("../data/peds_mrn_mapping_balanced_300.csv")
# Convert ID columns to string
df["pat_enc_csn_id_coded"] = df["pat_enc_csn_id_coded"].astype(str)
test_cohort["pat_enc_csn_id_coded"] = test_cohort["pat_enc_csn_id_coded"].astype(str)
df["anon_id"] = df["anon_id"].astype(str)
test_cohort["anon_id"] = test_cohort["anon_id"].astype(str)

# Convert datetime column - parse df's string to datetime with UTC timezone
df["blood_culture_order_datetime_utc"] = pd.to_datetime(df["blood_culture_order_datetime_utc"], utc=True)

# Now merge
result = pd.merge(df, test_cohort, on=["anon_id", "pat_enc_csn_id_coded", "blood_culture_order_datetime_utc"], how="inner")

# %%
result

# %%
peds_mrn_mapping_balanced_300= pd.read_csv("../data/peds_mrn_mapping_balanced_300.csv")
# Convert ID columns to string
peds_mrn_mapping_balanced_300["pat_enc_csn_id_coded"] = peds_mrn_mapping_balanced_300["pat_enc_csn_id_coded"].astype(str)
test_cohort["pat_enc_csn_id_coded"] = test_cohort["pat_enc_csn_id_coded"].astype(str)
peds_mrn_mapping_balanced_300["anon_id"] = peds_mrn_mapping_balanced_300["anon_id"].astype(str)
test_cohort["anon_id"] = test_cohort["anon_id"].astype(str)

# Convert datetime column - parse df's string to datetime with UTC timezone
peds_mrn_mapping_balanced_300["blood_culture_order_datetime_utc"] = pd.to_datetime(peds_mrn_mapping_balanced_300["blood_culture_order_datetime_utc"], utc=True)


merge_keys = ["anon_id", "pat_enc_csn_id_coded", "blood_culture_order_datetime_utc"]

# Drop overlapping non-key columns from test_cohort
cols_to_drop = [
    c for c in test_cohort.columns
    if c in peds_mrn_mapping_balanced_300.columns and c not in merge_keys
]

test_cohort_clean = test_cohort.drop(columns=cols_to_drop)

merge_keys = ["anon_id", "pat_enc_csn_id_coded", "blood_culture_order_datetime_utc"]
result = pd.merge(
    peds_mrn_mapping_balanced_300,
    test_cohort_clean,
    on=merge_keys,
    how="inner"
)

# # Now merge
# result = pd.merge(peds_mrn_mapping_balanced_300, test_cohort, on=["anon_id", "pat_enc_csn_id_coded", "blood_culture_order_datetime_utc"], how="inner")

# %%
result.columns

# %%
import pandas as pd
from google.cloud import bigquery

# =========================================================
# Goal:
# 1) For each row in `result`, fetch matching taken_time_jittered from BigQuery lab_result
# 2) Match on: anon_id, pat_enc_csn_id_coded, order_id_coded (lab) <-> order_proc_id_coded (local), order_time_jittered_utc <-> blood_culture_order_datetime_utc
# 3) Add columns: taken_time_jittered, candidate_epic_taken_time = taken_time_jittered - jitter_days
# =========================================================

# -----------------------------
# 0) Start from your in-memory dataframe
# -----------------------------
df = result.copy()

# Bridge column: local name -> lab name
df["order_id_coded"] = df["order_proc_id_coded"].astype(str)

# Normalize dtypes for join keys
df["anon_id"] = df["anon_id"].astype(str)
df["pat_enc_csn_id_coded"] = df["pat_enc_csn_id_coded"].astype(str)
df["order_id_coded"] = df["order_id_coded"].astype(str)
df["blood_culture_order_datetime_utc"] = pd.to_datetime(
    df["blood_culture_order_datetime_utc"], utc=True, errors="coerce"
)
df["jitter_days"] = pd.to_numeric(df["jitter_days"], errors="coerce")

# -----------------------------
# 1) Build unique key arrays for BigQuery (to avoid huge result)
# -----------------------------
keys_df = (
    df[["anon_id", "pat_enc_csn_id_coded", "order_id_coded", "blood_culture_order_datetime_utc"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

# Format UTC timestamp strings for BigQuery parsing
order_time_utc_strs = (
    keys_df["blood_culture_order_datetime_utc"]
    .dt.strftime("%Y-%m-%dT%H:%M:%S.%f")
    .str.rstrip("0").str.rstrip(".")
    + "Z"
).tolist()

anon_ids = keys_df["anon_id"].tolist()
csns = keys_df["pat_enc_csn_id_coded"].tolist()
order_ids = keys_df["order_id_coded"].tolist()

# -----------------------------
# 2) BigQuery query: zip arrays by OFFSET and join to lab_result
# -----------------------------
client = bigquery.Client()

query = """
WITH keys AS (
  SELECT
    anon_id,
    pat_enc_csn_id_coded,
    order_id_coded,
    PARSE_TIMESTAMP('%Y-%m-%dT%H:%M:%E*SZ', order_time_utc_str) AS order_time_jittered_utc
  FROM (
    SELECT
      anon_id,
      pat_enc_csn_id_coded,
      order_id_coded,
      order_time_utc_str
    FROM UNNEST(@anon_ids) AS anon_id WITH OFFSET off
    JOIN UNNEST(@csns) AS pat_enc_csn_id_coded WITH OFFSET off2 ON off2 = off
    JOIN UNNEST(@order_ids) AS order_id_coded WITH OFFSET off3 ON off3 = off
    JOIN UNNEST(@order_time_utc_strs) AS order_time_utc_str WITH OFFSET off4 ON off4 = off
  )
)
SELECT
  CAST(l.anon_id AS STRING) AS anon_id,
  CAST(l.pat_enc_csn_id_coded AS STRING) AS pat_enc_csn_id_coded,
  CAST(l.order_id_coded AS STRING) AS order_id_coded,
  l.order_time_jittered_utc,
  l.taken_time_jittered
FROM `som-nero-phi-jonc101.shc_core_2024.lab_result` l
JOIN keys k
ON CAST(l.anon_id AS STRING) = k.anon_id
AND CAST(l.pat_enc_csn_id_coded AS STRING) = k.pat_enc_csn_id_coded
AND CAST(l.order_id_coded AS STRING) = k.order_id_coded
AND l.order_time_jittered_utc = k.order_time_jittered_utc
"""

job_config = bigquery.QueryJobConfig(
    query_parameters=[
        bigquery.ArrayQueryParameter("anon_ids", "STRING", anon_ids),
        bigquery.ArrayQueryParameter("csns", "STRING", csns),
        bigquery.ArrayQueryParameter("order_ids", "STRING", order_ids),
        bigquery.ArrayQueryParameter("order_time_utc_strs", "STRING", order_time_utc_strs),
    ]
)

lab = client.query(query, job_config=job_config).to_dataframe()
print("lab rows fetched:", len(lab))

# -----------------------------
# 3) Normalize lab types and merge back
# -----------------------------
lab["anon_id"] = lab["anon_id"].astype(str)
lab["pat_enc_csn_id_coded"] = lab["pat_enc_csn_id_coded"].astype(str)
lab["order_id_coded"] = lab["order_id_coded"].astype(str)
lab["order_time_jittered_utc"] = pd.to_datetime(lab["order_time_jittered_utc"], utc=True, errors="coerce")
lab["taken_time_jittered"] = pd.to_datetime(lab["taken_time_jittered"], utc=True, errors="coerce")

# Rename lab timestamp column to match df column for merge
lab = lab.rename(columns={"order_time_jittered_utc": "blood_culture_order_datetime_utc"})

merge_keys = ["anon_id", "pat_enc_csn_id_coded", "order_id_coded", "blood_culture_order_datetime_utc"]

# Safety: if lab has duplicates, keep first (shouldn't happen if your key is truly unique)
lab = lab.drop_duplicates(subset=merge_keys, keep="first")

out = df.merge(
    lab[merge_keys + ["taken_time_jittered"]],
    on=merge_keys,
    how="left",
    validate="m:1"
)

# -----------------------------
# 4) Compute candidate_epic_taken_time
# -----------------------------
out["candidate_epic_taken_time"] = (
    out["taken_time_jittered"] - pd.to_timedelta(out["jitter_days"], unit="D")
)

# -----------------------------
# 5) Save
# -----------------------------
out_path = "../data/peds_mrn_mapping_balanced_300_with_taken_times.csv"
columns_to_keep = ["anon_id", "mrn", "pat_enc_csn_id_coded","blood_culture_order_datetime", "blood_culture_order_datetime_utc","taken_time_jittered", "jitter_days","candidate_epic_time",  "candidate_epic_taken_time", "final_label"]
out_columns_to_keep = out[columns_to_keep]
out_columns_to_keep.to_csv(out_path, index=False)

print("Saved:", out_path)
print("taken_time_jittered null rate:", out["taken_time_jittered"].isna().mean())
print("candidate_epic_taken_time null rate:", out["candidate_epic_taken_time"].isna().mean())

# %%
df1 = peds_mrn_mapping_balanced_300
df2 = out_columns_to_keep[peds_mrn_mapping_balanced_300.columns]

# Sort both by all columns, reset index, then compare
df1_sorted = df1.sort_values(by=df1.columns.tolist()).reset_index(drop=True)
df2_sorted = df2.sort_values(by=df2.columns.tolist()).reset_index(drop=True)

print("Same shape:", df1.shape == df2.shape)
print("Same content:", df1_sorted.equals(df2_sorted))

# %%
out_columns_to_keep

# %%
# import pandas as pd
# import numpy as np
# pd.set_option('display.max_columns', None)
# pd.read_csv("../data/balanced_100.csv")
